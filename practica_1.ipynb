# %% [markdown]
# <a href="https://colab.research.google.com/github/SergioGomezDavila/Reto-0-Ac-stica/blob/main/practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **laboratorio python sonidos**
# escri...aclaraciones, comentarios...

# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %% [markdown]
# Este código sirve para cargar la fuente de sonido que vamos a analizar.

# %%
if not os.path.exists('39150700348-point-mort-wav.wav'):
    # !wget http://s1.e-monsite.com/2008/07/02/39150700348-point-mort-wav.wav

# %%
from thinkdsp import read_wave

wave = read_wave('39150700348-point-mort-wav.wav')
wave.normalize()
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()
